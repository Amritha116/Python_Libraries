# %%
import numpy as np
a= np.array([1,2,3,5])
b= np.array([4,6,7,8])
c= np.concatenate((a,b))
c
# Out:
# array([1, 2, 3, 5, 4, 6, 7, 8])

# %%
a= np.array([1,2]),([3,4])
b= np.array([5,6]),([7,8])
#print(np.vstack((a,b)))
print(np.hstack((a,b)))
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %%
a= np.array([1,2,3])
print(np.tile(a,2))
# Out:
# [1 2 3 1 2 3]

# %%
print(np.repeat(a,2))
# Out:
# [1 1 2 2 3 3]

# %%
print(np.sum(a))
# Out:
# 6

# %%
print(np.mean(a))
# Out:
# 2.0

# %%
print(np.median(a))
# Out:
# 2.0

# %%
print(np.max(a))
# Out:
# 3

# %%
print(np.min(a))
# Out:
# 1

# %%
#where
a
# Out:
# array([1, 2, 3])

# %%
res= np.where(a<3,"low","high")
res
# Out:
# array(['low', 'low', 'high'], dtype='<U4')

# %%
arr=np.array([[1,3,2],[4,5,6]])
arr
# Out:
# array([[1, 3, 2],
#        [4, 5, 6]])

# %%
print(np.argwhere(arr>2))
# Out:
# [[0 1]
#  [1 0]
#  [1 1]
#  [1 2]]

# %%
a
# Out:
# array([1, 2, 3])

# %%
d=np.logical_and(a>1,a<3)
d
# Out:
# array([False,  True, False])

# %%
print(a[d])
# Out:
# [2]

# %%
b=([4,5,6])
b
# Out:
# [4, 5, 6]

# %%
d=np.logical_or(a>1,a<3)
d
# Out:
# array([ True,  True,  True])

# %%
arr=np.array([0,2,3,4,5])
arr
# Out:
# array([0, 2, 3, 4, 5])

# %%
print(np.nonzero(arr))
# Out:
# (array([1, 2, 3, 4], dtype=int64),)

# %%
#boradcasting
arr=np.array([[10,20],[30,40]])
arr.shape
# Out:
# (2, 2)

# %%
res=arr+100
res
# Out:
# array([[110, 120],
#        [130, 140]])

# %%
#vectorization to convert normal array this is a user define function
def cube(x):
    return x*x*x
ourfun =np.vectorize(cube)

# %%
a
# Out:
# array([1, 2, 3])

# %%
print(ourfun(a))
# Out:
# [ 1  8 27]

# %%
def squre(x):
    return x*x
ourfun =np.vectorize(squre)
print(ourfun(a))
# Out:
# [1 4 9]
